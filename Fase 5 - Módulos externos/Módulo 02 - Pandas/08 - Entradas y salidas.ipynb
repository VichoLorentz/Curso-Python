# %% [markdown]
# # Entradas y salidas

# %%
import numpy as np
import pandas as pd

# Definimos un dataframe con datos de ejemplos
df = pd.DataFrame(np.random.randn(10, 5), columns=["A", "B", "C", "D", "E"])

df
# Out:
#           A         B         C         D         E
# 0  0.034228  0.447229  1.082346  1.531512  1.152910
# 1  0.371922  2.945495 -1.037821 -0.003449 -0.100440
# 2 -0.439406 -0.454781 -0.448117  0.087000  0.248254
# 3 -0.954341 -0.142089 -0.068299 -0.105350 -0.888088
# 4  0.758183 -0.379467 -1.672592 -0.150871  0.199539
# 5 -1.497675 -0.138100  0.283825  1.034586 -0.987085
# 6  0.491942  0.708122 -0.110592  0.880498 -1.084235
# 7 -0.540296 -0.536824  1.831073  1.610607 -0.933925
# 8 -1.673268  0.126867  0.641673  0.621642  0.557654
# 9  0.004048 -0.017296 -1.457043 -0.447189 -0.978020

# %% [markdown]
# ## CSV
#
# ### Guardar a CSV

# %%
df.to_csv('datos.csv', index=False)

# %%
# Borramos el df de la memoria
del(df)

# %% [markdown]
# ### Cargar desde CSV

# %%
df = pd.read_csv('datos.csv')

df
# Out:
#           A         B         C         D         E
# 0 -0.587814 -1.826931 -1.543092  0.584127  1.591183
# 1  1.753232 -0.235550  2.641283 -0.467849  0.432604
# 2 -0.258634  0.083014 -1.349499  0.953855 -0.330437
# 3 -0.418297  1.167911 -0.003750  0.476619  0.329102
# 4  0.725402  0.776098  0.874464  1.306650  1.242229
# 5 -1.233851 -0.503244  1.135771  0.079776  0.854333
# 6  1.038565  1.420764 -0.880856  0.990069  0.299557
# 7  1.745571  0.563353  1.054682  1.379713  0.831537
# 8 -0.346192  1.744237  0.257775 -1.520293  1.292605
# 9 -0.910976  0.746282 -0.395216  0.051314 -1.216807

# %% [markdown]
# ## JSON
#
# ### Guardar a JSON

# %%
df.to_json('datos.json')

# %%
# Borramos el df de la memoria
del(df)

# %% [markdown]
# ### Cargar desde JSON

# %%
df = pd.read_json('datos.json')

df
# Out:
#           A         B         C         D         E
# 0 -0.587814 -1.826931 -1.543092  0.584127  1.591183
# 1  1.753232 -0.235550  2.641283 -0.467849  0.432604
# 2 -0.258634  0.083014 -1.349499  0.953855 -0.330437
# 3 -0.418297  1.167911 -0.003750  0.476619  0.329102
# 4  0.725402  0.776098  0.874464  1.306650  1.242229
# 5 -1.233851 -0.503244  1.135771  0.079776  0.854333
# 6  1.038565  1.420764 -0.880856  0.990069  0.299557
# 7  1.745571  0.563353  1.054682  1.379713  0.831537
# 8 -0.346192  1.744237  0.257775 -1.520293  1.292605
# 9 -0.910976  0.746282 -0.395216  0.051314 -1.216807

# %% [markdown]
# ## Excel
#
# Necesitamos instalar el módulo `openpyxl` para generar y leer este formato:
#
#     pip install openpyxl

# %%
# !pip install openpyxl
# Out:
# Collecting openpyxl
#   Downloading openpyxl-3.0.10-py2.py3-none-any.whl (242 kB)
#      ------------------------------------- 242.1/242.1 kB 15.5 MB/s eta 0:00:00
# Collecting et-xmlfile
#   Downloading et_xmlfile-1.1.0-py3-none-any.whl (4.7 kB)
# Installing collected packages: et-xmlfile, openpyxl
# Successfully installed et-xmlfile-1.1.0 openpyxl-3.0.10

# %% [markdown]
# ### Guardar a Excel

# %%
df.to_excel('datos.xlsx', sheet_name='Sheet1', index=False)

# %%
# Borramos el df de la memoria
del(df)

# %% [markdown]
# ### Cargar desde Excel

# %%
df = pd.read_excel('datos.xlsx', sheet_name='Sheet1')

df
# Out:
#           A         B         C         D         E
# 0 -0.587814 -1.826931 -1.543092  0.584127  1.591183
# 1  1.753232 -0.235550  2.641283 -0.467849  0.432604
# 2 -0.258634  0.083014 -1.349499  0.953855 -0.330437
# 3 -0.418297  1.167911 -0.003750  0.476619  0.329102
# 4  0.725402  0.776098  0.874464  1.306650  1.242229
# 5 -1.233851 -0.503244  1.135771  0.079776  0.854333
# 6  1.038565  1.420764 -0.880856  0.990069  0.299557
# 7  1.745571  0.563353  1.054682  1.379713  0.831537
# 8 -0.346192  1.744237  0.257775 -1.520293  1.292605
# 9 -0.910976  0.746282 -0.395216  0.051314 -1.216807

# %% [markdown]
# ## HTML
#
# Podemos extraer información directamente desde tablas de páginas web a partir de la URL.
#
# Esto se consigue haciendo web scrapping con los módulos `lxml` y `BeautifulSoup4`, por lo que necesitamos instalarlos:
#
#     pip install lxml BeautifulSoup4

# %%
# !pip install lxml BeautifulSoup4
# Out:
# Collecting lxml
#   Downloading lxml-4.9.1-cp310-cp310-win_amd64.whl (3.6 MB)
#      ---------------------------------------- 3.6/3.6 MB 56.8 MB/s eta 0:00:00
# Requirement already satisfied: BeautifulSoup4 in c:\users\vizio\appdata\local\programs\python\python310\lib\site-packages (4.11.1)
# Requirement already satisfied: soupsieve>1.2 in c:\users\vizio\appdata\local\programs\python\python310\lib\site-packages (from BeautifulSoup4) (2.3.2.post1)
# Installing collected packages: lxml
# Successfully installed lxml-4.9.1

# %% [markdown]
# Una vez instalado `lxml` y `BeautifulSoup4` reiniciamos el kernel (botón girando al lado de stop) y ya estaremos listos:

# %%
# Realizamos un scrapping de una tabla de la wikipedia
df = pd.read_html('https://web.archive.org/web/20220717170349/https://en.wikipedia.org/wiki/List_of_countries_by_past_fertility_rate')

# %% [markdown]
# Si se encuentra más de una tabla (como en el caso del ejemplo), podemos hacer referencia al primero a través del índice:

# %%
df[2]
# Out:
#     Country/dependent territory  1950–1955  1955–1960  1960–1965  1965–1970  \
# 0                   Afghanistan       7.45       7.45       7.45       7.45
# 1                       Albania       6.23       6.55       6.23       5.26
# 2                       Algeria       7.28       7.38       7.65       7.65
# 3                        Angola       7.30       7.35       7.60       7.60
# 4           Antigua and Barbuda       4.50       4.50       4.30       4.00
# ..                          ...        ...        ...        ...        ...
# 197           Western Sahara[7]       6.34       6.42       6.53       6.60
# 198                       Yemen       7.35       7.40       7.60       7.80
# 199                      Zambia       6.70       6.95       7.25       7.30
# 200                    Zimbabwe       6.80       7.00       7.30       7.40
# 201                       World       4.96       4.89       5.03       4.92
#
#      1970–1975  1975–1980  1980–1985  1985–1990  1990–1995  1995–2000  \
# 0         7.45       7.45       7.45       7.45       7.48       7.65
# 1         4.60       3.90       3.41       3.15       2.79       2.38
# 2         7.57       7.18       6.32       5.30       4.12       2.88
# 3         7.60       7.60       7.40       7.35       7.10       6.75
# 4         3.26       2.24       2.14       2.07       2.09       2.31
# ..         ...        ...        ...        ...        ...        ...
# 197       6.57       6.23       5.33       4.60       4.00       3.40
# 198       7.90       8.60       8.80       8.80       8.20       6.80
# 199       7.40       7.25       6.90       6.60       6.30       6.10
# 200       7.40       7.30       6.74       5.66       4.77       4.20
# 201       4.46       3.87       3.60       3.44       3.02       2.75
#
#      2000–2005  2005–2010  2010–2015
# 0         7.18       6.37       5.26
# 1         1.95       1.64       1.71
# 2         2.38       2.72       2.96
# 3         6.55       6.35       5.95
# 4         2.27       2.17       2.10
# ..         ...        ...        ...
# 197       2.85       2.55       2.60
# 198       5.90       5.00       4.40
# 199       5.95       5.60       5.20
# 200       4.00       4.00       4.00
# 201       2.63       2.57       2.52
#
# [202 rows x 14 columns]

# %% [markdown]
# Podemos hacer un poco de limpieza y dejar los datos presentables:

# %%
# Guardamos el dataframe
fertility_rate = df[2]

fertility_rate.head()
# Out:
#   Country/dependent territory  1950–1955  1955–1960  1960–1965  1965–1970  \
# 0                 Afghanistan       7.45       7.45       7.45       7.45
# 1                     Albania       6.23       6.55       6.23       5.26
# 2                     Algeria       7.28       7.38       7.65       7.65
# 3                      Angola       7.30       7.35       7.60       7.60
# 4         Antigua and Barbuda       4.50       4.50       4.30       4.00
#
#    1970–1975  1975–1980  1980–1985  1985–1990  1990–1995  1995–2000  \
# 0       7.45       7.45       7.45       7.45       7.48       7.65
# 1       4.60       3.90       3.41       3.15       2.79       2.38
# 2       7.57       7.18       6.32       5.30       4.12       2.88
# 3       7.60       7.60       7.40       7.35       7.10       6.75
# 4       3.26       2.24       2.14       2.07       2.09       2.31
#
#    2000–2005  2005–2010  2010–2015
# 0       7.18       6.37       5.26
# 1       1.95       1.64       1.71
# 2       2.38       2.72       2.96
# 3       6.55       6.35       5.95
# 4       2.27       2.17       2.10

# %%
# Renombramos la primera columna para que sea más fácil consultarla
fertility_rate.rename(columns = {'Country/dependent territory':'Country'}, inplace=True)

fertility_rate
# Out:
#                  Country  1950–1955  1955–1960  1960–1965  1965–1970  \
# 0            Afghanistan       7.45       7.45       7.45       7.45
# 1                Albania       6.23       6.55       6.23       5.26
# 2                Algeria       7.28       7.38       7.65       7.65
# 3                 Angola       7.30       7.35       7.60       7.60
# 4    Antigua and Barbuda       4.50       4.50       4.30       4.00
# ..                   ...        ...        ...        ...        ...
# 197    Western Sahara[7]       6.34       6.42       6.53       6.60
# 198                Yemen       7.35       7.40       7.60       7.80
# 199               Zambia       6.70       6.95       7.25       7.30
# 200             Zimbabwe       6.80       7.00       7.30       7.40
# 201                World       4.96       4.89       5.03       4.92
#
#      1970–1975  1975–1980  1980–1985  1985–1990  1990–1995  1995–2000  \
# 0         7.45       7.45       7.45       7.45       7.48       7.65
# 1         4.60       3.90       3.41       3.15       2.79       2.38
# 2         7.57       7.18       6.32       5.30       4.12       2.88
# 3         7.60       7.60       7.40       7.35       7.10       6.75
# 4         3.26       2.24       2.14       2.07       2.09       2.31
# ..         ...        ...        ...        ...        ...        ...
# 197       6.57       6.23       5.33       4.60       4.00       3.40
# 198       7.90       8.60       8.80       8.80       8.20       6.80
# 199       7.40       7.25       6.90       6.60       6.30       6.10
# 200       7.40       7.30       6.74       5.66       4.77       4.20
# 201       4.46       3.87       3.60       3.44       3.02       2.75
#
#      2000–2005  2005–2010  2010–2015
# 0         7.18       6.37       5.26
# 1         1.95       1.64       1.71
# 2         2.38       2.72       2.96
# 3         6.55       6.35       5.95
# 4         2.27       2.17       2.10
# ..         ...        ...        ...
# 197       2.85       2.55       2.60
# 198       5.90       5.00       4.40
# 199       5.95       5.60       5.20
# 200       4.00       4.00       4.00
# 201       2.63       2.57       2.52
#
# [202 rows x 14 columns]

# %% [markdown]
# Ahora podemos realizar consultas cómodamente:

# %%
# Índice de natalidad por país entre los años 2010-2015
fertility_rate[["Country", "2010–2015"]]
# Out:
#                  Country  2010–2015
# 0            Afghanistan       5.26
# 1                Albania       1.71
# 2                Algeria       2.96
# 3                 Angola       5.95
# 4    Antigua and Barbuda       2.10
# ..                   ...        ...
# 197    Western Sahara[7]       2.60
# 198                Yemen       4.40
# 199               Zambia       5.20
# 200             Zimbabwe       4.00
# 201                World       2.52
#
# [202 rows x 2 columns]

# %%
# Misma consulta aplicando el styler para esconder la primera columna
fertility_rate[["Country", "2010–2015"]].head().style.hide(axis=0)
# Out:
# <style type="text/css">
# </style>
# <table id="T_45ca8">
#   <thead>
#     <tr>
#       <th id="T_45ca8_level0_col0" class="col_heading level0 col0" >Country</th>
#       <th id="T_45ca8_level0_col1" class="col_heading level0 col1" >2010–2015</th>
#     </tr>
#   </thead>
#   <tbody>
#     <tr>
#       <td id="T_45ca8_row0_col0" class="data row0 col0" >Afghanistan</td>
#       <td id="T_45ca8_row0_col1" class="data row0 col1" >5.260000</td>
#     </tr>
#     <tr>
#       <td id="T_45ca8_row1_col0" class="data row1 col0" >Albania</td>
#       <td id="T_45ca8_row1_col1" class="data row1 col1" >1.710000</td>
#     </tr>
#     <tr>
#       <td id="T_45ca8_row2_col0" class="data row2 col0" >Algeria</td>
#       <td id="T_45ca8_row2_col1" class="data row2 col1" >2.960000</td>
#     </tr>
#     <tr>
#       <td id="T_45ca8_row3_col0" class="data row3 col0" >Angola</td>
#       <td id="T_45ca8_row3_col1" class="data row3 col1" >5.950000</td>
#     </tr>
#     <tr>
#       <td id="T_45ca8_row4_col0" class="data row4 col0" >Antigua and Barbuda</td>
#       <td id="T_45ca8_row4_col1" class="data row4 col1" >2.100000</td>
#     </tr>
#   </tbody>
# </table>

# %%
# Índice de natalidad por país entre los años 1985–1990 ordenado de más a menos (primeros resultados)
fertility_rate[["Country", "1985–1990"]].sort_values(by="1985–1990", ascending=False).head().style.hide(axis=0)
# Out:
# <style type="text/css">
# </style>
# <table id="T_e93ad">
#   <thead>
#     <tr>
#       <th id="T_e93ad_level0_col0" class="col_heading level0 col0" >Country</th>
#       <th id="T_e93ad_level0_col1" class="col_heading level0 col1" >1985–1990</th>
#     </tr>
#   </thead>
#   <tbody>
#     <tr>
#       <td id="T_e93ad_row0_col0" class="data row0 col0" >Yemen</td>
#       <td id="T_e93ad_row0_col1" class="data row0 col1" >8.800000</td>
#     </tr>
#     <tr>
#       <td id="T_e93ad_row1_col0" class="data row1 col0" >Oman</td>
#       <td id="T_e93ad_row1_col1" class="data row1 col1" >7.850000</td>
#     </tr>
#     <tr>
#       <td id="T_e93ad_row2_col0" class="data row2 col0" >Rwanda</td>
#       <td id="T_e93ad_row2_col1" class="data row2 col1" >7.800000</td>
#     </tr>
#     <tr>
#       <td id="T_e93ad_row3_col0" class="data row3 col0" >Niger</td>
#       <td id="T_e93ad_row3_col1" class="data row3 col1" >7.800000</td>
#     </tr>
#     <tr>
#       <td id="T_e93ad_row4_col0" class="data row4 col0" >Burundi</td>
#       <td id="T_e93ad_row4_col1" class="data row4 col1" >7.550000</td>
#     </tr>
#   </tbody>
# </table>

# %%
# Índice de natalidad por país entre los años 1985–1990 ordenado de más o menos (últimos resultados)
fertility_rate[["Country", "1985–1990"]].sort_values(by="1985–1990", ascending=False).tail().style.hide(axis=0)
# Out:
# <style type="text/css">
# </style>
# <table id="T_01e66">
#   <thead>
#     <tr>
#       <th id="T_01e66_level0_col0" class="col_heading level0 col0" >Country</th>
#       <th id="T_01e66_level0_col1" class="col_heading level0 col1" >1985–1990</th>
#     </tr>
#   </thead>
#   <tbody>
#     <tr>
#       <td id="T_01e66_row0_col0" class="data row0 col0" >Austria</td>
#       <td id="T_01e66_row0_col1" class="data row0 col1" >1.450000</td>
#     </tr>
#     <tr>
#       <td id="T_01e66_row1_col0" class="data row1 col0" >Guernsey and Jersey (UK)</td>
#       <td id="T_01e66_row1_col1" class="data row1 col1" >1.450000</td>
#     </tr>
#     <tr>
#       <td id="T_01e66_row2_col0" class="data row2 col0" >Germany</td>
#       <td id="T_01e66_row2_col1" class="data row2 col1" >1.430000</td>
#     </tr>
#     <tr>
#       <td id="T_01e66_row3_col0" class="data row3 col0" >Hong Kong (China)</td>
#       <td id="T_01e66_row3_col1" class="data row3 col1" >1.360000</td>
#     </tr>
#     <tr>
#       <td id="T_01e66_row4_col0" class="data row4 col0" >Italy</td>
#       <td id="T_01e66_row4_col1" class="data row4 col1" >1.350000</td>
#     </tr>
#   </tbody>
# </table>

# %%
# Vamos a transformar todas las columnas desde la segunda hasta la última a valores númericos
fertility_rate = fertility_rate[1:][:].apply(pd.to_numeric, errors='coerce')

# %%
# Ahora podemos consultar la media del índice de natalidad para cada año
fertility_rate.mean()[1:]
# Out:
# 1950–1955    5.447612
# 1955–1960    5.505622
# 1960–1965    5.501791
# 1965–1970    5.281940
# 1970–1975    4.991542
# 1975–1980    4.651343
# 1980–1985    4.393383
# 1985–1990    4.101592
# 1990–1995    3.738209
# 1995–2000    3.388955
# 2000–2005    3.120498
# 2005–2010    2.973234
# 2010–2015    2.837910
# dtype: float64

# %% [markdown]
# Con `Matplotlib`, que aprenderemos en la próxima sección, podemos graficar estos resultados fácilmente:

# %%
import matplotlib.pyplot as plt
plt.rcParams["figure.figsize"] = 10,5

fertility_rate.mean()[1:].plot(kind='line', xlabel="Períodos", ylabel="Media de natalidad mundial")
# Out:
# <AxesSubplot:xlabel='Períodos', ylabel='Media de natalidad mundial'>

# %% [markdown]
# La práctica hace el maestro, os animo a hacer vuestras propias pruebas y googlear cualquier cosa que se os ocurra para aprender mucho más.

# %%
df = pd.read_html('https://www.sii.cl/valores_y_fechas/uf/uf2022.htm')

# %%
df
# Out:
# [    Agosto   Agosto.1  Agosto.2  Agosto.3  Agosto.4  Agosto.5
#  0      1.0  33.426,92      11.0       NaN        21       NaN
#  1      2.0  33.436,58      12.0       NaN        22       NaN
#  2      3.0  33.446,25      13.0       NaN        23       NaN
#  3      4.0  33.455,92      14.0       NaN        24       NaN
#  4      5.0  33.465,59      15.0       NaN        25       NaN
#  5      6.0  33.475,26      16.0       NaN        26       NaN
#  6      7.0  33.484,94      17.0       NaN        27       NaN
#  7      8.0  33.494,62      18.0       NaN        28       NaN
#  8      9.0  33.504,30      19.0       NaN        29       NaN
#  9     10.0        NaN      20.0       NaN        30       NaN
#  10     NaN        NaN       NaN       NaN        31       NaN,
#      Julio    Julio.1  Julio.2    Julio.3  Julio.4    Julio.5
#  0     1.0  33.099,99     11.0  33.224,65       21  33.320,82
